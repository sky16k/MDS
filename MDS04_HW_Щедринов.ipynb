# %% [markdown]
# <a href="https://colab.research.google.com/github/sky16k/MDS/blob/main/MDS04_HW_%D0%A9%D0%B5%D0%B4%D1%80%D0%B8%D0%BD%D0%BE%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание "Функции одной переменной".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте значение первой и второй производной функции:
#
# $f(x) = x^5 + 4sin(2x) + cos(3x+3)$
#
# В точке x = 1.

# %%
import sympy as sym
import numpy as np

# %%
### YOUR CODE HERE

x = Symbol('x')
y = x**5+4*sin(2*x)+cos(3*x+3)

# %%
y_der1 = y.diff(x)
# print(
y_der1
# )
# Out:
# 5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x)

# %%
y_der2 = y_der1.diff(x)
y_der2
# Out:
# 20*x**3 - 16*sin(2*x) - 9*cos(3*x + 3)

# %%
print('Значение первой производной в точке x = 1:')
y_der1.subs(x,1).evalf()
# Out:
# Значение первой производной в точке x = 1:
# 2.50907180221964

# %%
print('Значение второй производной в точке x = 1:')
y_der2.subs(x,1).evalf()
# Out:
# Значение второй производной в точке x = 1:
# -3.19029140906420

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Постройте график первой и второй производной функции:
#
# $f(x) = sin^5(2x+1)$
#
# На отрезке [-5; 5].

# %%
import sympy as sym
import numpy as np

# %%
### YOUR CODE HERE
x = sym.Symbol('x')
y = (sym.sin(2*x+1))**5

# %%
y_der1 = y.diff(x)
y_der1
# Out:
# 10*sin(2*x + 1)**4*cos(2*x + 1)

# %%
y_der2 = y_der1.diff(x)
y_der2
# Out:
# -20*sin(2*x + 1)**5 + 80*sin(2*x + 1)**3*cos(2*x + 1)**2

# %%
p=sym.plotting.plot(y,y_der1, y_der2, (x, -5, 5))

# %%
p[1].line_color = 'red'
p[2].line_color = 'green'
p.legend = True
p.show()
