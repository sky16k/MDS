# %% [markdown]
# <a href="https://colab.research.google.com/github/sky16k/MDS/blob/main/MDS09_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание "Центральная предельная теорема и статистика".

# %% [markdown]
# ## Задание.

# %% [markdown]
# В этом задании нужно убедиться, что ЦПТ действительно работает.
#
# Создайте случайную величину из [любого выбранного вами распределения](https://docs.scipy.org/doc/scipy/reference/stats.html), для разных значений `n` сгенерируйте 1000 выборок размера `n`. Постройте гистрограммы средних этих выборок и сделайте выводы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns
# %matplotlib inline

# %%
rv = sts.pareto(7.62) ### YOUR CODE HERE
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
n1 = 2                # Размеры выборок 
# YOUR CODE HERE

a1 = np.array([])     # Массивы для сохранения средних по выборкам
# YOUR CODE HERE

samples_count = 1000  # Количество повторов генерации

for number in range(samples_count): 
    sample1 = rv.rvs(size=n1)               # На каждом цикле генерируем выборки указанных размеров
    # YOUR CODE HERE
    a1 = np.append(a1, sample1.mean())      # Считаем среднее по каждой выборке и добавляем в массив средних
    # YOUR CODE HERE

# %%
label_1 = 'sample of ' + str(n1) + ' histogram'   # Подписи для графиков
# YOUR CODE HERE
plt.hist(a1, density=1, label=label_1, histtype='step')         # Строим графики
# YOUR CODE HERE

plt.legend() 
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
fig = plt.figure(figsize=(12, 8))
ax = plt.axes()

for n in [2, 5, 10, 20, 50]:
    n1 = n                # Размеры выборок 
    # YOUR CODE HERE

    a1 = np.array([])     # Массивы для сохранения средних по выборкам
    # YOUR CODE HERE

    samples_count = 1000  # Количество повторов генерации

    for number in range(samples_count): 
        sample1 = rv.rvs(size=n1)               # На каждом цикле генерируем выборки указанных размеров
        # YOUR CODE HERE
        a1 = np.append(a1, sample1.mean())      # Считаем среднее по каждой выборке и добавляем в массив средних
        # YOUR CODE HERE
        # print(sample1)
    label_1 = 'sample of ' + str(n1) + ' histogram'   # Подписи для графиков
    # YOUR CODE HERE
    # plt.hist(a1, density=1, label=label_1, alpha=0.5)#, histtype='step')         # Строим графики
    # YOUR CODE HERE
    sns.kdeplot(a1, label=label_1)

ax.set_title('Распределение среднего от величины выборки')
plt.legend() 
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %% [markdown]
# По визуализации видим, что чем выше число элементов в выборках - тем ближе распределение средних в этих выборках к нормальному
